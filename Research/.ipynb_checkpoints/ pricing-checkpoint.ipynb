# %%
import pandas as pd

# %%
url_pets = "https://raw.githubusercontent.com/praktikum-hackathon/hackathon/dev/Research/data/pets.csv"
url_transactions = "https://raw.githubusercontent.com/praktikum-hackathon/hackathon/dev/Research/data/transactions.csv"
url_pricing = "https://raw.githubusercontent.com/praktikum-hackathon/hackathon/dev/Research/data/pricing.csv"

# %%
pets = pd.read_csv(url_pets)
transactions = pd.read_csv(url_transactions)
pricing = pd.read_csv(url_pricing)

# %%
len(pets)
# Out:
# 1554

# %%
pets.columns = ['id', 'nickname', 'profile_link', 'shelter', 
        'city', 'breed', 'type', 'birthday', 'sex', 
        'favorite', 'home', 'homeless', 'walk']

# %%
cats = pets[pets['type'] == 'Кошки']

# %%
cats_female = cats[cats['sex'] == 'девочка']

# %%
cats_male = cats[cats['sex'] == 'мальчик']

# %%
cats_male_home = cats_male[cats_male['home'] == 1]

# %%
cats_male_homeless = cats_male[cats_male['home'] != 1]

# %%
cats_female_home = cats_female[cats_female['home'] == 1]

# %%
cats_female_homeless = cats_female[cats_female['home'] != 1]

# %%
len(cats_male_home), len(cats_female_home)
# Out:
# (466, 607)

# %%
len(cats_male_homeless), len(cats_female_homeless)
# Out:
# (121, 205)

# %%
len(cats_male), len(cats_female)
# Out:
# (587, 812)

# %%
homeless_male_cats_ratio = len(cats_male_homeless) / len(cats_male)

# %%
homeless_female_cats_ratio = len(cats_female_homeless) / len(cats_female)

# %%
homeless_male_cats_ratio
# Out:
# 0.2061328790459966

# %%
homeless_female_cats_ratio
# Out:
# 0.2524630541871921

# %%
data = {'male': [len(cats_male_home),len(cats_female_home)],
'female': [len(cats_male_homeless),len(cats_female_homeless)]}

sex_home = pd.DataFrame(data, columns = ['male', 'female'], index=['home', 'homeless'])

# %%
sex_home = sex_home.T

# %%
sex_home['total'] = sex_home['male'] + sex_home['female']

# %%
sex_home['male_ratio'] = sex_home['male'] / sex_home['total']
sex_home['female_ratio'] = sex_home['female'] / sex_home['total']

# %%
sex_home.T
# Out:
#                     home    homeless
# male          466.000000  607.000000
# female        121.000000  205.000000
# total         587.000000  812.000000
# male_ratio      0.793867    0.747537
# female_ratio    0.206133    0.252463

# %%
len(cats)
# Out:
# 1399

# %%
cats[cats['home'] == 1]
# Out:
#         id     nickname                                      profile_link  \
# 0        1       Мадлен       https://teddyfood.com/ru/animals/madeleine/
# 1        2         Фифа            https://teddyfood.com/ru/animals/fifa/
# 2        3       Джинни           https://teddyfood.com/ru/animals/ginny/
# 3        4       Партос         https://teddyfood.com/ru/animals/porthos/
# 4        5      Самуэль          https://teddyfood.com/ru/animals/samuel/
# ...    ...          ...                                               ...
# 1537  1544          Аир         https://teddyfood.com/ru/animals/Air_ekb/
# 1538  1545          Аюр        https://teddyfood.com/ru/animals/Ayur_ekb/
# 1542  1549       Мансур   https://teddyfood.com/ru/animals/Mansur_YarKot/
# 1543  1550  Мистер Кусь   https://teddyfood.com/ru/animals/MisterKus_ekb/
# 1549  1556         Фева  https://teddyfood.com/ru/animals/Feva_Matroskin/
#
#                                      shelter          city       breed   type  \
# 0     Самарский приют для животных "НадеждА"        Самара  Без породы  Кошки
# 1                                     Ковчег      Смоленск    Мейн-кун  Кошки
# 2        Стационар для Животных "Сен Бернар"        Самара  Без породы  Кошки
# 3     Самарский приют для животных "НадеждА"        Самара  Без породы  Кошки
# 4     Самарский приют для животных "НадеждА"        Самара  Без породы  Кошки
# ...                                      ...           ...         ...    ...
# 1537                               Лёхин дом  Екатеринбург  Без породы  Кошки
# 1538                               Лёхин дом  Екатеринбург  Без породы  Кошки
# 1542                 Приют для кошек "ЯрКот"     Ярославль  Без породы  Кошки
# 1543                               Лёхин дом  Екатеринбург  Без породы  Кошки
# 1549                               Матроскин         Пермь  Без породы  Кошки
#
#         birthday      sex  favorite  home  homeless  walk
# 0     2015-09-23  девочка         0     1         0     0
# 1     2000-03-03  девочка         0     1         0     0
# 2     2015-07-01  девочка         0     1         0     0
# 3     2013-11-01  мальчик         0     1         0     0
# 4     2015-04-01  мальчик         1     1         0     0
# ...          ...      ...       ...   ...       ...   ...
# 1537  2019-09-08  мальчик         0     1         0     0
# 1538  2019-09-08  мальчик         0     1         0     0
# 1542  2017-02-01  мальчик         5     1         0     0
# 1543  2016-01-18  мальчик         0     1         0     0
# 1549  2017-11-30  девочка         0     1         0     0
#
# [1073 rows x 13 columns]

# %%
cats_female_walk = cats_female[cats_female['walk'] > 0]

# %%
cats_male_walk = cats_male[cats_male['walk'] > 0]

# %%
cats_female_walk
# Out:
#         id  nickname                                      profile_link  \
# 25      27  Марианна        https://teddyfood.com/ru/animals/marianne/
# 43      45    Оливия          https://teddyfood.com/ru/animals/olivia/
# 44      46  Изабелла          https://teddyfood.com/ru/animals/isabel/
# 45      47     Беата           https://teddyfood.com/ru/animals/beata/
# 47      49     Монро           https://teddyfood.com/ru/animals/monro/
# ...    ...       ...                                               ...
# 1398  1405   Галатея  https://teddyfood.com/ru/animals/Galatea_sherem/
# 1430  1437     Корса  https://teddyfood.com/ru/animals/Korsa_Layushki/
# 1441  1448      Пуся    https://teddyfood.com/ru/animals/Pusya_Yarcot/
# 1498  1505     Наяда      https://teddyfood.com/ru/animals/Najada_Lex/
# 1517  1524     Шкода     https://teddyfood.com/ru/animals/Shkoda_yard/
#
#                                  shelter             city  \
# 25    Частный Московский приют "МУРКОША"           Москва
# 43    Частный Московский приют "МУРКОША"           Москва
# 44    Частный Московский приют "МУРКОША"           Москва
# 45    Частный Московский приют "МУРКОША"           Москва
# 47    Частный Московский приют "МУРКОША"           Москва
# ...                                  ...              ...
# 1398                Шереметьевский приют           Москва
# 1430                     Лаюшки и Мяушки           Москва
# 1441             Приют для кошек "ЯрКот"        Ярославль
# 1498                           Лёхин дом     Екатеринбург
# 1517                         Котланд-Ярд  Санкт-Петербург
#
#                                     breed    type    birthday      sex  \
# 25                             Без породы   Кошки  2015-07-08  девочка
# 43                             Без породы   Кошки  2014-08-29  девочка
# 44                             Без породы   Кошки  2014-08-29  девочка
# 45                             Без породы   Кошки  2014-09-25  девочка
# 47                             Без породы   Кошки  2011-08-24  девочка
# ...                                   ...     ...         ...      ...
# 1398  Американский стаффордширский терьер  Собаки  2016-11-24  девочка
# 1430                           Без породы  Собаки  2019-10-15  девочка
# 1441                           Без породы   Кошки  2015-01-22  девочка
# 1498                             Сиамская   Кошки  2019-12-01  девочка
# 1517                           Без породы   Кошки  2018-06-16  девочка
#
#       favorite  home  homeless  walk
# 25           0     1         0     1
# 43           0     1         0     2
# 44          16     1         0     1
# 45          19     1         0     3
# 47           0     1         0     1
# ...        ...   ...       ...   ...
# 1398         4     1         0     1
# 1430         3     1         1     2
# 1441        25     0         0     1
# 1498         4     0         0     1
# 1517        12     0         0     1
#
# [115 rows x 13 columns]

# %%
cats_male_walk
# Out:
#         id   nickname                                       profile_link  \
# 86      88     Байкал           https://teddyfood.com/ru/animals/baikal/
# 87      89       Мася            https://teddyfood.com/ru/animals/masya/
# 91      93      Жорик            https://teddyfood.com/ru/animals/jorik/
# 92      94        Рон              https://teddyfood.com/ru/animals/ron/
# 120    122       Гоша            https://teddyfood.com/ru/animals/gosha/
# ...    ...        ...                                                ...
# 1431  1438        Кен     https://teddyfood.com/ru/animals/Ken_Layushki/
# 1484  1491  Себастьян  https://teddyfood.com/ru/animals/Sebastian_kot...
# 1513  1520    Дональд    https://teddyfood.com/ru/animals/Donald_Matros/
# 1514  1521    Павлуша  https://teddyfood.com/ru/animals/Pavlusha_Matros/
# 1516  1523       Лекс         https://teddyfood.com/ru/animals/Lex_yard/
#
#                                  shelter             city  \
# 86                            Мокрый нос            Киров
# 87                            Мокрый нос            Киров
# 91                            Мокрый нос            Киров
# 92                            Мокрый нос            Киров
# 120   Частный Московский приют "МУРКОША"           Москва
# ...                                  ...              ...
# 1431                     Лаюшки и Мяушки           Москва
# 1484                             Котофей             Сочи
# 1513                           Матроскин            Пермь
# 1514                           Матроскин            Пермь
# 1516                         Котланд-Ярд  Санкт-Петербург
#
#                            breed    type    birthday      sex  favorite  home  \
# 86                    Без породы  Собаки  2014-05-14  мальчик        68     1
# 87                    Без породы  Собаки  2016-03-10  мальчик         5     1
# 91                    Без породы  Собаки  2015-09-23  мальчик        72     1
# 92                    Без породы  Собаки  2015-06-18  мальчик        63     0
# 120                   Без породы   Кошки  2014-12-20  мальчик        10     1
# ...                          ...     ...         ...      ...       ...   ...
# 1431                  Без породы  Собаки  2019-10-15  мальчик        15     1
# 1484  Британская вислоухая кошка   Кошки  2013-09-12  мальчик        22     0
# 1513                  Без породы   Кошки  2017-06-15  мальчик         1     1
# 1514                  Без породы   Кошки  2017-11-15  мальчик         2     0
# 1516                     Тайская   Кошки  2015-06-02  мальчик        14     0
#
#       homeless  walk
# 86           0     2
# 87           1     1
# 91           0     1
# 92           0     3
# 120          2    10
# ...        ...   ...
# 1431         0     3
# 1484         0     1
# 1513         0     1
# 1514         0     1
# 1516         0     2
#
# [82 rows x 13 columns]

# %%
pets['type'].unique()
# Out:
# array(['Кошки', 'Собаки'], dtype=object)

# %%
pricing.columns = ['user_id', 'shelter', 'transaction_time', 'service_name', 'transaction_sum']

# %%
len(pricing.service_name.unique())
# Out:
# 71

# %%
popular_services = pd.pivot_table(pricing, columns = 'service_name', aggfunc='count')

# %%
popular_services
# Out:
# service_name       Новогодний КотоНабор  1 КотоДень  1 КотоМесяц  \
# shelter                             350        3231           14
# transaction_sum                     350        3231           14
# transaction_time                    350        3231           14
# user_id                             350        3231           14
#
# service_name      1 КотоНеделя  1 ПёсоДень  1 ПёсоМесяц  1 ПёсоНеделя  \
# shelter                    219         591            7            61
# transaction_sum            219         591            7            61
# transaction_time           219         591            7            61
# user_id                    219         591            7            61
#
# service_name      Анализ пцр  Антивирусные капли в нос и в глаза  \
# shelter                    1                                  12
# transaction_sum            1                                  12
# transaction_time           1                                  12
# user_id                    1                                  12
#
# service_name      Биохимический анализ крови  ...  \
# shelter                                  191  ...
# transaction_sum                          191  ...
# transaction_time                         191  ...
# user_id                                  191  ...
#
# service_name      Рекламировать питомца (пакет Standart)  Рентген питомца  \
# shelter                                              238               15
# transaction_sum                                      238               15
# transaction_time                                     238               15
# user_id                                              238               15
#
# service_name      Стерилизация  Тест на коронавирус  УЗИ питомца  \
# shelter                    254                  182           44
# transaction_sum            254                  182           44
# transaction_time           254                  182           44
# user_id                    254                  182           44
#
# service_name      Уколы Амоксицилин  Улучшить микрофлору кишечника  \
# shelter                           2                             12
# transaction_sum                   2                             12
# transaction_time                  2                             12
# user_id                           2                             12
#
# service_name      Успокаивающий ошейник с феромонами   Химиотерапия  Шприцы
# shelter                                            50            15      30
# transaction_sum                                    50            15      30
# transaction_time                                   50            15      30
# user_id                                            50            15      30
#
# [4 rows x 71 columns]

# %%
df = pets.groupby('city')['shelter'].count()

# %%
df = pets.groupby('shelter')['city'].count()

# %%
df = pets.groupby('city')['shelter']

# %%
df
# Out:
# shelter
# 4 лапы                                          9
# Добрые сердца                                  28
# Ковчег                                          1
# Кот и Пёс                                      63
# Котланд-Ярд                                     4
# Котофей                                        88
# Кошачий приют "ДОМИК"                         113
# Лаюшки и Мяушки                                20
# Люськин дом                                    54
# Лёхин дом                                      48
# Матроскин                                     330
# Мокрый нос                                     46
# Приют для кошек "Потеряшка"                    25
# Приют для кошек "ЯрКот"                        51
# Реабилитационный центр ЗОО Дом                  5
# Республика котов                               12
# Республика кошек                               16
# Самарский приют для животных "НадеждА"        350
# Стационар для Животных "Сен Бернар"             2
# Убежище                                        23
# ФлагманВет                                     46
# Центральный приют Спб для бездомных кошек!     40
# Частный Московский приют "МУРКОША"            139
# Шереметьевский приют                           41
# Name: city, dtype: int64

# %%
pets[pets['shelter'] == 'Котофей'].head(50)
# Out:
#         id        nickname                                       profile_link  \
# 325    328            Соня          https://teddyfood.com/ru/animals/Sonia_p/
# 326    329            Амур             https://teddyfood.com/ru/animals/Amur/
# 341    345          Аватар           https://teddyfood.com/ru/animals/Avatar/
# 343    347          Кузина          https://teddyfood.com/ru/animals/Cousina/
# 349    353            Пьер           https://teddyfood.com/ru/animals/Pierre/
# 359    363      Мандаринка       https://teddyfood.com/ru/animals/Mandarinka/
# 360    364         Сникерс         https://teddyfood.com/ru/animals/Snickers/
# 361    365       Канапешка       https://teddyfood.com/ru/animals/Kanapeshka/
# 383    387          Феликс          https://teddyfood.com/ru/animals/Felix_p/
# 388    392            Вася        https://teddyfood.com/ru/animals/Vasya_cat/
# 418    422           Герда          https://teddyfood.com/ru/animals/Gerda_k/
# 439    443            Лиза         https://teddyfood.com/ru/animals/Liza_p_k/
# 451    455      Констанция       https://teddyfood.com/ru/animals/Konstancia/
# 459    463         Графиня         https://teddyfood.com/ru/animals/Countess/
# 536    540           Рыжик           https://teddyfood.com/ru/animals/Ryzhik/
# 544    548            Джем            https://teddyfood.com/ru/animals/Jam_k/
# 577    581           Бэлла  https://teddyfood.com/ru/animals/Bella__perm_k...
# 592    596            Барс             https://teddyfood.com/ru/animals/Bars/
# 593    597           Брайс            https://teddyfood.com/ru/animals/Bryce/
# 600    604             Шон             https://teddyfood.com/ru/animals/Shon/
# 637    641        Бармалей         https://teddyfood.com/ru/animals/Barmaley/
# 1051  1057        Джинджер     https://teddyfood.com/ru/animals/Ginger_sochi/
# 1052  1058           Азура            https://teddyfood.com/ru/animals/Azura/
# 1053  1059            Лулу             https://teddyfood.com/ru/animals/Lulu/
# 1054  1060          Тристи           https://teddyfood.com/ru/animals/Tristi/
# 1093  1100           Афина     https://teddyfood.com/ru/animals/Athena_sochi/
# 1094  1101            Гера             https://teddyfood.com/ru/animals/Hera/
# 1095  1102           Борей            https://teddyfood.com/ru/animals/Borey/
# 1099  1106           Алмаз            https://teddyfood.com/ru/animals/Almaz/
# 1100  1107            Яшма     https://teddyfood.com/ru/animals/Yashma_sochy/
# 1118  1125           Будда           https://teddyfood.com/ru/animals/Buddha/
# 1119  1126           Юнона           https://teddyfood.com/ru/animals/Yunona/
# 1208  1215       Агриппина  https://teddyfood.com/ru/animals/Agrippina_sochi/
# 1209  1216        Анжелина   https://teddyfood.com/ru/animals/Angelina_sochi/
# 1210  1217           Джоли            https://teddyfood.com/ru/animals/Jolie/
# 1215  1222            Усик             https://teddyfood.com/ru/animals/Usik/
# 1223  1230          Рошель         https://teddyfood.com/ru/animals/Rochelle/
# 1224  1231            Тефи             https://teddyfood.com/ru/animals/Tefi/
